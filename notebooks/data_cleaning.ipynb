# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("data/raw/EV_Adoption_and_Range_Anxiety_Dataset.csv")
df.head()
# Out:
#   Buyer_ID  Age  Gender  Annual_Income_USD City_Type  Daily_Commute_km  \
# 0  EV00001   56    Male            44906.0     Rural              18.1
# 1  EV00002   36    Male            88754.0     Rural               5.0
# 2  EV00003   42    Male           155958.0     Urban              32.2
# 3  EV00004   31    Male            37059.0     Rural              89.9
# 4  EV00005   48  Female            48552.0     Rural              71.0
#
#    Number_of_Cars_Owned Current_Car_Type  Charging_Stations_Near_Home  \
# 0                     1            Truck                            1
# 1                     1              SUV                            2
# 2                     2            Sedan                           14
# 3                     1            Sedan                            2
# 4                     1            Sedan                            2
#
#    Charging_Stations_Near_Work Home_Charging_Possible  \
# 0                            0                    Yes
# 1                            3                    Yes
# 2                            3                     No
# 3                            1                    Yes
# 4                            0                    Yes
#
#    Environmental_Concern_Level Subsidy_Available Range_Anxiety_Level  \
# 0                          4.0               Yes                 Low
# 1                          1.0               Yes                 Low
# 2                          2.0               Yes              Medium
# 3                          4.0                No                 Low
# 4                          3.0               Yes                 Low
#
#   Will_Buy_EV
# 0          No
# 1          No
# 2         Yes
# 3          No
# 4          No

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Buyer_ID                     10000 non-null  str
#  1   Age                          10000 non-null  int64
#  2   Gender                       10000 non-null  str
#  3   Annual_Income_USD            9822 non-null   float64
#  4   City_Type                    10000 non-null  str
#  5   Daily_Commute_km             9819 non-null   float64
#  6   Number_of_Cars_Owned         10000 non-null  int64
#  7   Current_Car_Type             10000 non-null  str
#  8   Charging_Stations_Near_Home  10000 non-null  int64
#  9   Charging_Stations_Near_Work  10000 non-null  int64
#  10  Home_Charging_Possible       10000 non-null  str
#  11  Environmental_Concern_Level  9816 non-null   float64
#  12  Subsidy_Available            10000 non-null  str
#  13  Range_Anxiety_Level          10000 non-null  str
#  14  Will_Buy_EV                  10000 non-null  str
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.1 MB

# %%
cols_to_treat = ["Annual_Income_USD","Daily_Commute_km","Environmental_Concern_Level"]
for i in cols_to_treat:
    plt.figure(figsize=(5,6))
    sns.histplot(df[i])

# %%
df.describe()
# Out:
#                 Age  Annual_Income_USD  Daily_Commute_km  \
# count  10000.000000        9822.000000       9819.000000
# mean      46.936200       85378.485848         41.105418
# std       12.945968       32838.684167         23.351276
# min       25.000000       30000.000000          5.000000
# 25%       36.000000       61369.500000         23.250000
# 50%       47.000000       84708.000000         40.200000
# 75%       58.000000      107383.250000         57.000000
# max       69.000000      223345.000000        135.500000
#
#        Number_of_Cars_Owned  Charging_Stations_Near_Home  \
# count          10000.000000                 10000.000000
# mean               1.859900                     5.346900
# std                0.855421                     4.049074
# min                1.000000                     0.000000
# 25%                1.000000                     2.000000
# 50%                2.000000                     5.000000
# 75%                2.000000                     8.000000
# max                4.000000                    14.000000
#
#        Charging_Stations_Near_Work  Environmental_Concern_Level
# count                 10000.000000                  9816.000000
# mean                      7.458200                     2.982783
# std                       5.259374                     1.413784
# min                       0.000000                     1.000000
# 25%                       3.000000                     2.000000
# 50%                       6.000000                     3.000000
# 75%                      11.000000                     4.000000
# max                      19.000000                     5.000000

# %%
num_cols = df.describe().columns
num_cols
# Out:
# Index(['Age', 'Annual_Income_USD', 'Daily_Commute_km', 'Number_of_Cars_Owned',
#        'Charging_Stations_Near_Home', 'Charging_Stations_Near_Work',
#        'Environmental_Concern_Level'],
#       dtype='str')

# %% [markdown]
# # Null imputation

# %%
for i in num_cols :
    plt.figure(figsize=(5,6))
    sns.boxplot(df[i])

# %%
med = df.groupby("Number_of_Cars_Owned")["Annual_Income_USD"].median()
med
# Out:
# Number_of_Cars_Owned
# 1    84758.0
# 2    84287.0
# 3    84906.0
# 4    86877.0
# Name: Annual_Income_USD, dtype: float64

# %%
df["Annual_Income_USD"] = df["Annual_Income_USD"].fillna(df["Number_of_Cars_Owned"].map(med))

# %%
df["Annual_Income_USD"].isna().sum()
# Out:
# np.int64(0)

# %%
med_km = df.groupby("Age")["Daily_Commute_km"].median()
med_km
# Out:
# Age
# 25    39.15
# 26    41.50
# 27    36.90
# 28    42.60
# 29    42.80
# 30    40.90
# 31    41.10
# 32    39.30
# 33    38.90
# 34    41.90
# 35    40.40
# 36    38.35
# 37    40.45
# 38    40.85
# 39    40.60
# 40    43.80
# 41    41.20
# 42    38.60
# 43    38.10
# 44    41.15
# 45    44.00
# 46    38.80
# 47    42.20
# 48    41.20
# 49    37.00
# 50    39.60
# 51    37.25
# 52    36.60
# 53    40.95
# 54    40.50
# 55    36.80
# 56    38.80
# 57    43.90
# 58    39.30
# 59    39.00
# 60    37.20
# 61    41.05
# 62    41.20
# 63    35.75
# 64    40.90
# 65    42.40
# 66    41.75
# 67    38.95
# 68    39.90
# 69    38.30
# Name: Daily_Commute_km, dtype: float64

# %%
df["Daily_Commute_km"] = df["Daily_Commute_km"].fillna(df["Age"].map(med_km))

# %%
df["Daily_Commute_km"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Environmental_Concern_Level"]=df["Environmental_Concern_Level"].fillna(df["Environmental_Concern_Level"].median())

# %%
df.isna().sum()
# Out:
# Buyer_ID                       0
# Age                            0
# Gender                         0
# Annual_Income_USD              0
# City_Type                      0
# Daily_Commute_km               0
# Number_of_Cars_Owned           0
# Current_Car_Type               0
# Charging_Stations_Near_Home    0
# Charging_Stations_Near_Work    0
# Home_Charging_Possible         0
# Environmental_Concern_Level    0
# Subsidy_Available              0
# Range_Anxiety_Level            0
# Will_Buy_EV                    0
# dtype: int64

# %% [markdown]
# # Handling outliers

# %%
for i in num_cols :
    
    plt.figure(figsize=(5,6))
    sns.boxplot(df[i])

# %%
sns.boxplot(df["Annual_Income_USD"].clip(0,174000))
# Out:
# <Axes: ylabel='Annual_Income_USD'>

# %%
df["Annual_Income_USD"]=df["Annual_Income_USD"].clip(0,174000)

# %%
sns.boxplot(df["Daily_Commute_km"].clip(0,106))
# Out:
# <Axes: ylabel='Daily_Commute_km'>

# %%
df["Daily_Commute_km"]=df["Daily_Commute_km"].clip(0,106)

# %%
final_df = df.drop(["Buyer_ID"],axis=1)

# %%
final_df
# Out:
#       Age  Gender  Annual_Income_USD City_Type  Daily_Commute_km  \
# 0      56    Male            44906.0     Rural              18.1
# 1      36    Male            88754.0     Rural               5.0
# 2      42    Male           155958.0     Urban              32.2
# 3      31    Male            37059.0     Rural              89.9
# 4      48  Female            48552.0     Rural              71.0
# ...   ...     ...                ...       ...               ...
# 9995   50    Male            61279.0     Urban              71.4
# 9996   34    Male           108208.0     Urban              48.0
# 9997   60  Female            97743.0     Urban               9.0
# 9998   31  Female           103628.0     Urban              81.8
# 9999   64   Other            59052.0  Suburban              24.0
#
#       Number_of_Cars_Owned Current_Car_Type  Charging_Stations_Near_Home  \
# 0                        1            Truck                            1
# 1                        1              SUV                            2
# 2                        2            Sedan                           14
# 3                        1            Sedan                            2
# 4                        1            Sedan                            2
# ...                    ...              ...                          ...
# 9995                     1            Sedan                            8
# 9996                     2        Hatchback                            9
# 9997                     2            Sedan                           10
# 9998                     2              SUV                           10
# 9999                     2        Hatchback                            1
#
#       Charging_Stations_Near_Work Home_Charging_Possible  \
# 0                               0                    Yes
# 1                               3                    Yes
# 2                               3                     No
# 3                               1                    Yes
# 4                               0                    Yes
# ...                           ...                    ...
# 9995                            3                     No
# 9996                            7                     No
# 9997                            3                     No
# 9998                           10                    Yes
# 9999                            9                    Yes
#
#       Environmental_Concern_Level Subsidy_Available Range_Anxiety_Level  \
# 0                             4.0               Yes                 Low
# 1                             1.0               Yes                 Low
# 2                             2.0               Yes              Medium
# 3                             4.0                No                 Low
# 4                             3.0               Yes                 Low
# ...                           ...               ...                 ...
# 9995                          3.0               Yes              Medium
# 9996                          5.0                No                 Low
# 9997                          5.0               Yes                 Low
# 9998                          1.0               Yes                 Low
# 9999                          5.0               Yes                 Low
#
#      Will_Buy_EV
# 0             No
# 1             No
# 2            Yes
# 3             No
# 4             No
# ...          ...
# 9995          No
# 9996          No
# 9997          No
# 9998          No
# 9999          No
#
# [10000 rows x 14 columns]

# %%
final_df["Current_Car_Type"].value_counts()
# Out:
# Current_Car_Type
# Sedan        4000
# SUV          3486
# Hatchback    1523
# Truck         991
# Name: count, dtype: int64

# %%
final_df["Range_Anxiety_Level"].value_counts()
# Out:
# Range_Anxiety_Level
# Low       8310
# Medium    1523
# High       167
# Name: count, dtype: int64

# %%
final_df.to_csv("data/processed/modified_data.csv",index=False)

# %%
test = pd.read_csv("data/processed/modified_data.csv")

# %%
test.columns
# Out:
# Index(['Age', 'Gender', 'Annual_Income_USD', 'City_Type', 'Daily_Commute_km',
#        'Number_of_Cars_Owned', 'Current_Car_Type',
#        'Charging_Stations_Near_Home', 'Charging_Stations_Near_Work',
#        'Home_Charging_Possible', 'Environmental_Concern_Level',
#        'Subsidy_Available', 'Range_Anxiety_Level', 'Will_Buy_EV'],
#       dtype='str')

# %%
num_cols
# Out:
# Index(['Age', 'Annual_Income_USD', 'Daily_Commute_km', 'Number_of_Cars_Owned',
#        'Charging_Stations_Near_Home', 'Charging_Stations_Near_Work',
#        'Environmental_Concern_Level'],
#       dtype='str')

# %%
cat_cols = test.drop(num_cols,axis=1).columns
cat_cols
# Out:
# Index(['Gender', 'City_Type', 'Current_Car_Type', 'Home_Charging_Possible',
#        'Subsidy_Available', 'Range_Anxiety_Level', 'Will_Buy_EV'],
#       dtype='str')

# %%
df2 = pd.read_csv("data/processed/scaled_data.csv")

# %%
df2['Will_Buy_EV']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Will_Buy_EV, Length: 10000, dtype: int64
